# %%
from qiime2 import Artifact
from qiime2.plugin.testing import TestPluginBase
from pandas import DataFrame as DataFrame

from q2_types_genomics.eggnog import NOG, ArbitraryHeaderTSVFmt

# %%
import os

# %%
filename = 'sampleannotations.txt'

filepath = os.path.join("./tests/data/", filename)

# %%
ff = ArbitraryHeaderTSVFmt(filepath, 'r')

# %%
ff.view(DataFrame)
# Out:
#                                    #query_name           seed_eggNOG_ortholog  \
# 0                                  k129_5480_1               856793.MICA_1589
# 1                                  k129_5480_2             1469613.JT55_09850
# 2                                  k129_5480_3   985867.AEWF01000001_gene1800
# 3                                  k129_5480_4               856793.MICA_1598
# 4                                  k129_5480_5  1528106.JRJE01000008_gene1538
# ...                                        ...                            ...
# 1370                            k129_5480_1788          1294273.roselon_02816
# 1371                            k129_5480_1789   501479.ACNW01000063_gene2789
# 1372                    # 1372 queries scanned                            NaN
# 1373  # Total time (seconds): 7.36770224571228                            NaN
# 1374                        # Rate: 186.22 q/s                            NaN
#
# ...

# %%
test_file = Artifact.import_data('FeatureData[NOG]', filepath)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 test_file = Artifact.import_data('FeatureData[NOG]', filepath)
#
# File ~/work/qiime2/qiime2/qiime2/sdk/result.py:278, in Artifact.import_data(cls, type, view, view_type)
#     275     format_ = view_type
#     277 provenance_capture = archive.ImportProvenanceCapture(format_, md5sums)
# --> 278 return cls._from_view(type_, view, view_type, provenance_capture,
#     279                       validate_level='max')
#
# File ~/work/qiime2/qiime2/qiime2/sdk/result.py:306, in Artifact._from_view(cls, type, view, view_type, provenance_capture, validate_level)
#     303 recorder = provenance_capture.transformation_recorder('return')
#     304 transformation = from_type.make_transformation(to_type,
#     305                                                recorder=recorder)
# ...
